# %% [markdown]
# ##  [quiz] 2021년 11월 1일~ 2022년 1월 27일 코로나 확진자를 학습하고 이후 확진자수 예측하라

# %%
#3일 동안의 확진자 수 추이를 보고 다음 날의 확진자 수를 예측
#따라서 인공지능은 3일 동안의 확진자 수를 보고 다음 날의 확진자 수가 어떻게 되었는지 학습
#만약 100일 동안의 확진자 수가 있다면 가장 먼저 1, 2, 3일차의 확진자 수가 어떻게 변하였는지 살펴보고 4일차의 확진자 수를 학습한다
#그리고 2, 3, 4일차의 확진자 수가 어떻게 변하였는지 살펴보고 5일차의 확진자 수를 학습한다
#이러한 방식으로 계속 학습하여 97, 98, 99일차의 확진자 수로 100일차의 확진자 수를 학습한다
#연속된 데이터의 형태에서 그 패턴을 찾아내는 순환 신경망(RNN) 방식으로, RNN의 기본적인 형태를 설계하고 학습시켜 본다

# %% [markdown]
# # RNN-코로나19 확진자수 예측

# %% [markdown]
# #### 필요한 라이브러리 임포트

# %%
from keras.models import Sequential
from keras.layers import SimpleRNN, Dense
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split

import math
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# #### 코로나 데이터 가져오기

# %%
'''import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split'''
# Step 1: Handle Missing Values
'''covid_19['new_patient'].fillna(0, inplace=True)'''  # Assuming NaNs represent zero new patients
# Step 2: Feature Scaling
'''scaler = MinMaxScaler()
covid_19[['deathCnt', 'decideCnt', 'new_patient']] = scaler.fit_transform(covid_19[['deathCnt', 'decideCnt', 'new_patient']])'''
# Step 3: Convert Time Series to Sequences
# Assuming you want to predict 'decideCnt' based on previous 'new_patient' values
# You may need to adjust the sequence length and target column based on your requirements
'''sequence_length = 10
X, y = [], []
for i in range(len(covid_19) - sequence_length):
    X.append(covid_19.iloc[i:(i + sequence_length)][['deathCnt', 'decideCnt', 'new_patient']].values)
    y.append(covid_19.iloc[i + sequence_length]['decideCnt'])
X = np.array(X)
y = np.array(y)'''
# Step 6: Split Data
''''X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=False)'''
# Now you can proceed to train your RNN model using X_train, y_train
# and evaluate it using X_test, y_test
'''from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import SimpleRNN, Dense'''
# Define the RNN model
'''model = Sequential()'''
# Add the SimpleRNN layer
# Adjust the number of units and input_shape according to your data and requirements
'''model.add(SimpleRNN(units=50, input_shape=(X_train.shape[1], X_train.shape[2])))'''
# Add the output layer
# Assuming you want to predict a single value (decideCnt)
'''model.add(Dense(units=1))'''
# Compile the model
# Adjust the loss function and optimizer according to your task
'''model.compile(optimizer='adam', loss='mean_squared_error')'''
# Print the summary of the model
'''model.summary()'''

# %%
covid_19 = pd.read_csv('./covid_2021101_20220127.csv')
covid_19.drop('Unnamed: 0', axis=1, inplace=True)

# %%
covid_19.isna().sum()
covid_19['new_patient'].fillna(0, inplace=True)
covid_19.isna().sum()
# Out:
# deathCnt       0
# createDate     0
# decideCnt      0
# new_patient    0
# dtype: int64

# %%
covid_19['new_patient'].max(), covid_19['new_patient'].min(),
# Out:
# (14515.0, 0.0)

# %%
scaler = MinMaxScaler()
covid_19[['deathCnt', 'decideCnt', 'new_patient']] = scaler.fit_transform(covid_19[['deathCnt', 'decideCnt', 'new_patient']])

# %%
covid_19.iloc[0:(0 + 10)][['deathCnt', 'decideCnt', 'new_patient']].values
# Out:
# array([[0.        , 0.        , 0.        ],
#        [0.00421496, 0.00386277, 0.10940406],
#        [0.0089568 , 0.01035018, 0.18374096],
#        [0.01527924, 0.01638758, 0.17099552],
#        [0.02054795, 0.02208687, 0.16141922],
#        [0.02581665, 0.02755021, 0.15473648],
#        [0.02871444, 0.03296246, 0.1532897 ],
#        [0.03213909, 0.03722902, 0.12084051],
#        [0.03688093, 0.04140558, 0.11829142],
#        [0.04056902, 0.04730433, 0.16706855]])

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import SimpleRNN, Dense

# %%
sequence_length = 3
X, y = [], []
for i in range(len(covid_19) - sequence_length):
    X.append(covid_19.iloc[i:(i + sequence_length)][['deathCnt', 'decideCnt', 'new_patient']].values)
    y.append(covid_19.iloc[i + sequence_length]['decideCnt'])
X = np.array(X)
y = np.array(y)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=False)

# %%
X_train, len(X_train), X_train[0]
# Out:
# (array([[[0.        , 0.        , 0.        ],
#          [0.00421496, 0.00386277, 0.10940406],
#          [0.0089568 , 0.01035018, 0.18374096]],
#
#         [[0.00421496, 0.00386277, 0.10940406],
#          [0.0089568 , 0.01035018, 0.18374096],
#          [0.01527924, 0.01638758, 0.17099552]],
#
#         [[0.0089568 , 0.01035018, 0.18374096],
#          [0.01527924, 0.01638758, 0.17099552],
#          [0.02054795, 0.02208687, 0.16141922]],
#
#         [[0.01527924, 0.01638758, 0.17099552],
#          [0.02054795, 0.02208687, 0.16141922],
#          [0.02581665, 0.02755021, 0.15473648]],
#
#         [[0.02054795, 0.02208687, 0.16141922],
#          [0.02581665, 0.02755021, 0.15473648],
#          [0.02871444, 0.03296246, 0.1532897 ]],
#
#         [[0.02581665, 0.02755021, 0.15473648],
#          [0.02871444, 0.03296246, 0.1532897 ],
#          [0.03213909, 0.03722902, 0.12084051]],
#
#         [[0.02871444, 0.03296246, 0.1532897 ],
#          [0.03213909, 0.03722902, 0.12084051],
#          [0.03688093, 0.04140558, 0.11829142]],
#
#         [[0.03213909, 0.03722902, 0.12084051],
#          [0.03688093, 0.04140558, 0.11829142],
#          [0.04056902, 0.04730433, 0.16706855]],
#
#         [[0.03688093, 0.04140558, 0.11829142],
#          [0.04056902, 0.04730433, 0.16706855],
#          [0.04610116, 0.0534293 , 0.17347571]],
#
#         [[0.04056902, 0.04730433, 0.16706855],
#          [0.04610116, 0.0534293 , 0.17347571],
#          [0.05084299, 0.0591894 , 0.16314158]],
#
#         [[0.04610116, 0.0534293 , 0.17347571],
#          [0.05084299, 0.0591894 , 0.16314158],
#          [0.05927292, 0.06484247, 0.16011023]],
#
#         [[0.05084299, 0.0591894 , 0.16314158],
#          [0.05927292, 0.06484247, 0.16011023],
#          [0.06454162, 0.0707242 , 0.16658629]],
#
#         [[0.05927292, 0.06484247, 0.16011023],
#          [0.06454162, 0.0707242 , 0.16658629],
#          [0.06770285, 0.07559888, 0.13806407]],
#
#         [[0.06454162, 0.0707242 , 0.16658629],
#          [0.06770285, 0.07559888, 0.13806407],
#          [0.07349842, 0.08076059, 0.14619359]],
#
#         [[0.06770285, 0.07559888, 0.13806407],
#          [0.07349842, 0.08076059, 0.14619359],
#          [0.07903056, 0.08851775, 0.21970375]],
#
#         [[0.07349842, 0.08076059, 0.14619359],
#          [0.07903056, 0.08851775, 0.21970375],
#          [0.08667018, 0.09652545, 0.22679986]],
#
#         [[0.07903056, 0.08851775, 0.21970375],
#          [0.08667018, 0.09652545, 0.22679986],
#          [0.09404636, 0.10390315, 0.20895625]],
#
#         [[0.08667018, 0.09652545, 0.22679986],
#          [0.09404636, 0.10390315, 0.20895625],
#          [0.10168599, 0.11169923, 0.22080606]],
#
#         [[0.09404636, 0.10390315, 0.20895625],
#          [0.10168599, 0.11169923, 0.22080606],
#          [0.10958904, 0.11928855, 0.21495005]],
#
#         [[0.10168599, 0.11169923, 0.22080606],
#          [0.10958904, 0.11928855, 0.21495005],
#          [0.11591149, 0.12616516, 0.19476404]],
#
#         [[0.10958904, 0.11928855, 0.21495005],
#          [0.11591149, 0.12616516, 0.19476404],
#          [0.12381454, 0.13272554, 0.18580779]],
#
#         [[0.11591149, 0.12616516, 0.19476404],
#          [0.12381454, 0.13272554, 0.18580779],
#          [0.13277134, 0.14273031, 0.28336204]],
#
#         [[0.12381454, 0.13272554, 0.18580779],
#          [0.13277134, 0.14273031, 0.28336204],
#          [0.14304531, 0.15230696, 0.27123665]],
#
#         [[0.13277134, 0.14273031, 0.28336204],
#          [0.14304531, 0.15230696, 0.27123665],
#          [0.15331928, 0.16178388, 0.26841199]],
#
#         [[0.14304531, 0.15230696, 0.27123665],
#          [0.15331928, 0.16178388, 0.26841199],
#          [0.16701791, 0.17167675, 0.2801929 ]],
#
#         [[0.15331928, 0.16178388, 0.26841199],
#          [0.16701791, 0.17167675, 0.2801929 ],
#          [0.18177028, 0.18122422, 0.27040992]],
#
#         [[0.16701791, 0.17167675, 0.2801929 ],
#          [0.18177028, 0.18122422, 0.27040992],
#          [0.19020021, 0.18926841, 0.22783328]],
#
#         [[0.18177028, 0.18122422, 0.27040992],
#          [0.19020021, 0.18926841, 0.22783328],
#          [0.20179136, 0.19664124, 0.20881846]],
#
#         [[0.19020021, 0.18926841, 0.22783328],
#          [0.20179136, 0.19664124, 0.20881846],
#          [0.21074816, 0.20910037, 0.35287633]],
#
#         [[0.20179136, 0.19664124, 0.20881846],
#          [0.21074816, 0.20910037, 0.35287633],
#          [0.22312961, 0.22190249, 0.36259042]],
#
#         [[0.21074816, 0.20910037, 0.35287633],
#          [0.22312961, 0.22190249, 0.36259042],
#          [0.23208641, 0.23392864, 0.34061316]],
#
#         [[0.22312961, 0.22190249, 0.36259042],
#          [0.23208641, 0.23392864, 0.34061316],
#          [0.25052687, 0.24694724, 0.36872201]],
#
#         [[0.23208641, 0.23392864, 0.34061316],
#          [0.25052687, 0.24694724, 0.36872201],
#          [0.26185458, 0.25941368, 0.35308302]],
#
#         [[0.25052687, 0.24694724, 0.36872201],
#          [0.26185458, 0.25941368, 0.35308302],
#          [0.27265543, 0.2699317 , 0.29789873]],
#
#         [[0.26185458, 0.25941368, 0.35308302],
#          [0.27265543, 0.2699317 , 0.29789873],
#          [0.28951528, 0.28197974, 0.34123321]],
#
#         [[0.27265543, 0.2699317 , 0.29789873],
#          [0.28951528, 0.28197974, 0.34123321],
#          [0.3061117 , 0.29942788, 0.49417844]],
#
#         [[0.28951528, 0.28197974, 0.34123321],
#          [0.3061117 , 0.29942788, 0.49417844],
#          [0.3211275 , 0.31736738, 0.50809507]],
#
#         [[0.3061117 , 0.29942788, 0.49417844],
#          [0.3211275 , 0.31736738, 0.50809507],
#          [0.33508957, 0.33378172, 0.46489838]],
#
#         [[0.3211275 , 0.31736738, 0.50809507],
#          [0.33508957, 0.33378172, 0.46489838],
#          [0.35616438, 0.35075309, 0.48067516]],
#
#         [[0.33508957, 0.33378172, 0.46489838],
#          [0.35616438, 0.35075309, 0.48067516],
#          [0.36722866, 0.36700446, 0.46028247]],
#
#         [[0.35616438, 0.35075309, 0.48067516],
#          [0.36722866, 0.36700446, 0.46028247],
#          [0.37776607, 0.38115173, 0.40068894]],
#
#         [[0.36722866, 0.36700446, 0.46028247],
#          [0.37776607, 0.38115173, 0.40068894],
#          [0.40252898, 0.39469331, 0.38353427]],
#
#         [[0.37776607, 0.38115173, 0.40068894],
#          [0.40252898, 0.39469331, 0.38353427],
#          [0.42096944, 0.41378581, 0.54075095]],
#
#         [[0.40252898, 0.39469331, 0.38353427],
#          [0.42096944, 0.41378581, 0.54075095],
#          [0.43730242, 0.43231883, 0.52490527]],
#
#         [[0.42096944, 0.41378581, 0.54075095],
#          [0.43730242, 0.43231883, 0.52490527],
#          [0.45653319, 0.45040184, 0.51215983]],
#
#         [[0.43730242, 0.43231883, 0.52490527],
#          [0.45653319, 0.45040184, 0.51215983],
#          [0.47049526, 0.46818323, 0.50361695]],
#
#         [[0.45653319, 0.45040184, 0.51215983],
#          [0.47049526, 0.46818323, 0.50361695],
#          [0.4910432 , 0.48334485, 0.42941784]],
#
#         [[0.47049526, 0.46818323, 0.50361695],
#          [0.4910432 , 0.48334485, 0.42941784],
#          [0.5052687 , 0.49627588, 0.36624182]],
#
#         [[0.4910432 , 0.48334485, 0.42941784],
#          [0.5052687 , 0.49627588, 0.36624182],
#          [0.51896733, 0.50890529, 0.35769893]],
#
#         [[0.5052687 , 0.49627588, 0.36624182],
#          [0.51896733, 0.50890529, 0.35769893],
#          [0.53951528, 0.52703209, 0.51339993]],
#
#         [[0.51896733, 0.50890529, 0.35769893],
#          [0.53951528, 0.52703209, 0.51339993],
#          [0.56822972, 0.54385022, 0.47633483]],
#
#         [[0.53951528, 0.52703209, 0.51339993],
#          [0.56822972, 0.54385022, 0.47633483],
#          [0.58298209, 0.55901183, 0.42941784]],
#
#         [[0.56822972, 0.54385022, 0.47633483],
#          [0.58298209, 0.55901183, 0.42941784],
#          [0.61064278, 0.57321748, 0.4023424 ]],
#
#         [[0.58298209, 0.55901183, 0.42941784],
#          [0.61064278, 0.57321748, 0.4023424 ],
#          [0.62881981, 0.58638447, 0.37292456]],
#
#         [[0.61064278, 0.57321748, 0.4023424 ],
#          [0.62881981, 0.58638447, 0.37292456],
#          [0.64330875, 0.59660816, 0.28956252]],
#
#         [[0.62881981, 0.58638447, 0.37292456],
#          [0.64330875, 0.59660816, 0.28956252],
#          [0.65542677, 0.60600724, 0.26620737]],
#
#         [[0.64330875, 0.59660816, 0.28956252],
#          [0.65542677, 0.60600724, 0.26620737],
#          [0.66491043, 0.61915963, 0.3725112 ]],
#
#         [[0.65542677, 0.60600724, 0.26620737],
#          [0.66491043, 0.61915963, 0.3725112 ],
#          [0.6841412 , 0.63140471, 0.34681364]],
#
#         [[0.66491043, 0.61915963, 0.3725112 ],
#          [0.6841412 , 0.63140471, 0.34681364],
#          [0.7125922 , 0.64325815, 0.33572167]],
#
#         [[0.6841412 , 0.63140471, 0.34681364],
#          [0.7125922 , 0.64325815, 0.33572167],
#          [0.72892518, 0.65399753, 0.3041681 ]],
#
#         [[0.7125922 , 0.64325815, 0.33572167],
#          [0.72892518, 0.65399753, 0.3041681 ],
#          [0.74710221, 0.66331634, 0.26393386]],
#
#         [[0.72892518, 0.65399753, 0.3041681 ],
#          [0.74710221, 0.66331634, 0.26393386],
#          [0.75658588, 0.67091782, 0.21529452]],
#
#         [[0.74710221, 0.66331634, 0.26393386],
#          [0.75658588, 0.67091782, 0.21529452],
#          [0.77002107, 0.67826633, 0.20812952]],
#
#         [[0.75658588, 0.67091782, 0.21529452],
#          [0.77002107, 0.67826633, 0.20812952],
#          [0.78503688, 0.68906895, 0.30595935]],
#
#         [[0.77002107, 0.67826633, 0.20812952],
#          [0.78503688, 0.68906895, 0.30595935],
#          [0.79794521, 0.69909561, 0.28398209]],
#
#         [[0.78503688, 0.68906895, 0.30595935],
#          [0.79794521, 0.69909561, 0.28398209],
#          [0.80979979, 0.70812738, 0.25580434]],
#
#         [[0.79794521, 0.69909561, 0.28398209],
#          [0.80979979, 0.70812738, 0.25580434],
#          [0.82402529, 0.71665807, 0.24161213]],
#
#         [[0.80979979, 0.70812738, 0.25580434],
#          [0.82402529, 0.71665807, 0.24161213],
#          [0.83746048, 0.72485794, 0.23224251]]]),
#  68,
#  array([[0.        , 0.        , 0.        ],
#         [0.00421496, 0.00386277, 0.10940406],
#         [0.0089568 , 0.01035018, 0.18374096]]))

# %%
X_train.shape
# Out:
# (68, 3, 3)

# %%
model = Sequential()
model.add(SimpleRNN(units=100, input_shape=(X_train.shape[1], X_train.shape[2])))
model.add(Dense(units=1))
# Out:
# WARNING:tensorflow:From c:\anaconda3\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.

# %%
model.compile(optimizer='adam', loss='mse', metrics='mae')
model.summary()
# Out:
# WARNING:tensorflow:From c:\anaconda3\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn (SimpleRNN)      (None, 100)               10400
#
#  dense (Dense)               (None, 1)                 101
#
# =================================================================
# Total params: 10501 (41.02 KB)
# Trainable params: 10501 (41.02 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
hist = model.fit(X_train, y_train, validation_data=(X_test, y_test), verbose=1, epochs=100)
# Out:
# Epoch 1/100
# WARNING:tensorflow:From c:\anaconda3\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
# WARNING:tensorflow:From c:\anaconda3\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 3/3 [==============================] - 2s 132ms/step - loss: 0.0637 - mae: 0.1875 - val_loss: 0.0072 - val_mae: 0.0811
# Epoch 2/100
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0227 - mae: 0.1430 - val_loss: 0.0338 - val_mae: 0.1812
# Epoch 3/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0151 - mae: 0.1128 - val_loss: 0.0030 - val_mae: 0.0379
# Epoch 4/100
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0012 - mae: 0.0254 - val_loss: 0.0311 - val_mae: 0.1640
# Epoch 5/100
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0102 - mae: 0.0934 - val_loss: 0.0136 - val_mae: 0.0983
# Epoch 6/100
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0035 - mae: 0.0514 - val_loss: 0.0074 - val_mae: 0.0788
# Epoch 7/100
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0030 - mae: 0.0366 - val_loss: 0.0183 - val_mae: 0.1278
# Epoch 8/100
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0053 - mae: 0.0549 - val_loss: 0.0043 - val_mae: 0.0598
# Epoch 9/100
# 3/3 [==============================] - 0s 14ms/step - loss: 8.9759e-04 - mae: 0.0200 - val_loss: 0.0069 - val_mae: 0.0672
# Epoch 10/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0010 - mae: 0.0264 - val_loss: 0.0155 - val_mae: 0.1145
# Epoch 11/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0015 - mae: 0.0312 - val_loss: 0.0072 - val_mae: 0.0724
# Epoch 12/100
# 3/3 [==============================] - 0s 13ms/step - loss: 1.7399e-04 - mae: 0.0110 - val_loss: 0.0017 - val_mae: 0.0302
# Epoch 13/100
# 3/3 [==============================] - 0s 13ms/step - loss: 7.4932e-04 - mae: 0.0252 - val_loss: 0.0016 - val_mae: 0.0304
# Epoch 14/100
# 3/3 [==============================] - 0s 12ms/step - loss: 4.9656e-04 - mae: 0.0203 - val_loss: 0.0044 - val_mae: 0.0506
# Epoch 15/100
# 3/3 [==============================] - 0s 13ms/step - loss: 1.4598e-04 - mae: 0.0093 - val_loss: 0.0079 - val_mae: 0.0769
# Epoch 16/100
# 3/3 [==============================] - 0s 15ms/step - loss: 3.9100e-04 - mae: 0.0152 - val_loss: 0.0049 - val_mae: 0.0535
# Epoch 17/100
# 3/3 [==============================] - 0s 13ms/step - loss: 9.7995e-05 - mae: 0.0071 - val_loss: 0.0020 - val_mae: 0.0328
# Epoch 18/100
# 3/3 [==============================] - 0s 14ms/step - loss: 2.6789e-04 - mae: 0.0124 - val_loss: 0.0019 - val_mae: 0.0332
# Epoch 19/100
# 3/3 [==============================] - 0s 14ms/step - loss: 2.5618e-04 - mae: 0.0117 - val_loss: 0.0027 - val_mae: 0.0340
# Epoch 20/100
# 3/3 [==============================] - 0s 12ms/step - loss: 8.5486e-05 - mae: 0.0072 - val_loss: 0.0046 - val_mae: 0.0501
# Epoch 21/100
# 3/3 [==============================] - 0s 12ms/step - loss: 1.8498e-04 - mae: 0.0109 - val_loss: 0.0047 - val_mae: 0.0521
# Epoch 22/100
# 3/3 [==============================] - 0s 12ms/step - loss: 1.1246e-04 - mae: 0.0079 - val_loss: 0.0033 - val_mae: 0.0390
# Epoch 23/100
# 3/3 [==============================] - 0s 12ms/step - loss: 6.4011e-05 - mae: 0.0061 - val_loss: 0.0026 - val_mae: 0.0331
# Epoch 24/100
# 3/3 [==============================] - 0s 13ms/step - loss: 9.5145e-05 - mae: 0.0082 - val_loss: 0.0033 - val_mae: 0.0397
# Epoch 25/100
# 3/3 [==============================] - 0s 14ms/step - loss: 5.2984e-05 - mae: 0.0056 - val_loss: 0.0045 - val_mae: 0.0520
# Epoch 26/100
# 3/3 [==============================] - 0s 14ms/step - loss: 9.4725e-05 - mae: 0.0073 - val_loss: 0.0041 - val_mae: 0.0480
# Epoch 27/100
# 3/3 [==============================] - 0s 14ms/step - loss: 4.9179e-05 - mae: 0.0054 - val_loss: 0.0025 - val_mae: 0.0328
# Epoch 28/100
# 3/3 [==============================] - 0s 13ms/step - loss: 9.3535e-05 - mae: 0.0079 - val_loss: 0.0026 - val_mae: 0.0333
# Epoch 29/100
# 3/3 [==============================] - 0s 12ms/step - loss: 5.9161e-05 - mae: 0.0060 - val_loss: 0.0039 - val_mae: 0.0461
# Epoch 30/100
# 3/3 [==============================] - 0s 13ms/step - loss: 7.2161e-05 - mae: 0.0061 - val_loss: 0.0046 - val_mae: 0.0527
# Epoch 31/100
# 3/3 [==============================] - 0s 12ms/step - loss: 9.9599e-05 - mae: 0.0075 - val_loss: 0.0032 - val_mae: 0.0394
# Epoch 32/100
# 3/3 [==============================] - 0s 12ms/step - loss: 7.3780e-05 - mae: 0.0068 - val_loss: 0.0023 - val_mae: 0.0312
# Epoch 33/100
# 3/3 [==============================] - 0s 13ms/step - loss: 9.1541e-05 - mae: 0.0079 - val_loss: 0.0036 - val_mae: 0.0436
# Epoch 34/100
# 3/3 [==============================] - 0s 13ms/step - loss: 5.0688e-05 - mae: 0.0055 - val_loss: 0.0044 - val_mae: 0.0520
# Epoch 35/100
# 3/3 [==============================] - 0s 12ms/step - loss: 6.4587e-05 - mae: 0.0063 - val_loss: 0.0034 - val_mae: 0.0427
# Epoch 36/100
# 3/3 [==============================] - 0s 12ms/step - loss: 5.0513e-05 - mae: 0.0056 - val_loss: 0.0027 - val_mae: 0.0352
# Epoch 37/100
# 3/3 [==============================] - 0s 17ms/step - loss: 5.4616e-05 - mae: 0.0059 - val_loss: 0.0032 - val_mae: 0.0401
# Epoch 38/100
# 3/3 [==============================] - 0s 14ms/step - loss: 4.5463e-05 - mae: 0.0049 - val_loss: 0.0035 - val_mae: 0.0424
# Epoch 39/100
# 3/3 [==============================] - 0s 14ms/step - loss: 4.7852e-05 - mae: 0.0052 - val_loss: 0.0027 - val_mae: 0.0351
# Epoch 40/100
# 3/3 [==============================] - 0s 13ms/step - loss: 4.5207e-05 - mae: 0.0054 - val_loss: 0.0027 - val_mae: 0.0346
# Epoch 41/100
# 3/3 [==============================] - 0s 14ms/step - loss: 4.4290e-05 - mae: 0.0053 - val_loss: 0.0032 - val_mae: 0.0395
# Epoch 42/100
# 3/3 [==============================] - 0s 14ms/step - loss: 4.0374e-05 - mae: 0.0048 - val_loss: 0.0034 - val_mae: 0.0429
# Epoch 43/100
# 3/3 [==============================] - 0s 13ms/step - loss: 3.9141e-05 - mae: 0.0048 - val_loss: 0.0032 - val_mae: 0.0409
# Epoch 44/100
# 3/3 [==============================] - 0s 14ms/step - loss: 3.8198e-05 - mae: 0.0048 - val_loss: 0.0030 - val_mae: 0.0391
# Epoch 45/100
# 3/3 [==============================] - 0s 22ms/step - loss: 4.0095e-05 - mae: 0.0049 - val_loss: 0.0030 - val_mae: 0.0389
# Epoch 46/100
# 3/3 [==============================] - 0s 16ms/step - loss: 3.6693e-05 - mae: 0.0048 - val_loss: 0.0026 - val_mae: 0.0349
# Epoch 47/100
# 3/3 [==============================] - 0s 13ms/step - loss: 4.2476e-05 - mae: 0.0052 - val_loss: 0.0028 - val_mae: 0.0363
# Epoch 48/100
# 3/3 [==============================] - 0s 14ms/step - loss: 3.6029e-05 - mae: 0.0048 - val_loss: 0.0033 - val_mae: 0.0417
# Epoch 49/100
# 3/3 [==============================] - 0s 15ms/step - loss: 3.6641e-05 - mae: 0.0046 - val_loss: 0.0032 - val_mae: 0.0406
# Epoch 50/100
# 3/3 [==============================] - 0s 14ms/step - loss: 3.3268e-05 - mae: 0.0044 - val_loss: 0.0030 - val_mae: 0.0388
# Epoch 51/100
# 3/3 [==============================] - 0s 11ms/step - loss: 3.1199e-05 - mae: 0.0044 - val_loss: 0.0028 - val_mae: 0.0371
# Epoch 52/100
# 3/3 [==============================] - 0s 13ms/step - loss: 3.2331e-05 - mae: 0.0045 - val_loss: 0.0030 - val_mae: 0.0388
# Epoch 53/100
# 3/3 [==============================] - 0s 13ms/step - loss: 3.0451e-05 - mae: 0.0042 - val_loss: 0.0032 - val_mae: 0.0408
# Epoch 54/100
# 3/3 [==============================] - 0s 12ms/step - loss: 3.0984e-05 - mae: 0.0043 - val_loss: 0.0029 - val_mae: 0.0381
# Epoch 55/100
# 3/3 [==============================] - 0s 13ms/step - loss: 3.1481e-05 - mae: 0.0045 - val_loss: 0.0029 - val_mae: 0.0384
# Epoch 56/100
# 3/3 [==============================] - 0s 13ms/step - loss: 2.9703e-05 - mae: 0.0042 - val_loss: 0.0033 - val_mae: 0.0423
# Epoch 57/100
# 3/3 [==============================] - 0s 13ms/step - loss: 3.4130e-05 - mae: 0.0045 - val_loss: 0.0030 - val_mae: 0.0396
# Epoch 58/100
# 3/3 [==============================] - 0s 14ms/step - loss: 2.9282e-05 - mae: 0.0043 - val_loss: 0.0027 - val_mae: 0.0363
# Epoch 59/100
# 3/3 [==============================] - 0s 12ms/step - loss: 2.9111e-05 - mae: 0.0043 - val_loss: 0.0028 - val_mae: 0.0374
# Epoch 60/100
# 3/3 [==============================] - 0s 13ms/step - loss: 2.9283e-05 - mae: 0.0043 - val_loss: 0.0027 - val_mae: 0.0364
# Epoch 61/100
# 3/3 [==============================] - 0s 12ms/step - loss: 2.8529e-05 - mae: 0.0043 - val_loss: 0.0026 - val_mae: 0.0352
# Epoch 62/100
# 3/3 [==============================] - 0s 13ms/step - loss: 3.0351e-05 - mae: 0.0044 - val_loss: 0.0031 - val_mae: 0.0406
# Epoch 63/100
# 3/3 [==============================] - 0s 12ms/step - loss: 3.0556e-05 - mae: 0.0042 - val_loss: 0.0032 - val_mae: 0.0415
# Epoch 64/100
# 3/3 [==============================] - 0s 13ms/step - loss: 2.6810e-05 - mae: 0.0040 - val_loss: 0.0026 - val_mae: 0.0357
# Epoch 65/100
# 3/3 [==============================] - 0s 13ms/step - loss: 3.5461e-05 - mae: 0.0047 - val_loss: 0.0029 - val_mae: 0.0394
# Epoch 66/100
# 3/3 [==============================] - 0s 12ms/step - loss: 2.6246e-05 - mae: 0.0039 - val_loss: 0.0035 - val_mae: 0.0459
# Epoch 67/100
# 3/3 [==============================] - 0s 13ms/step - loss: 3.5404e-05 - mae: 0.0047 - val_loss: 0.0029 - val_mae: 0.0391
# Epoch 68/100
# 3/3 [==============================] - 0s 13ms/step - loss: 2.6523e-05 - mae: 0.0040 - val_loss: 0.0026 - val_mae: 0.0358
# Epoch 69/100
# 3/3 [==============================] - 0s 12ms/step - loss: 2.6164e-05 - mae: 0.0041 - val_loss: 0.0030 - val_mae: 0.0400
# Epoch 70/100
# 3/3 [==============================] - 0s 13ms/step - loss: 2.4780e-05 - mae: 0.0039 - val_loss: 0.0031 - val_mae: 0.0417
# Epoch 71/100
# 3/3 [==============================] - 0s 13ms/step - loss: 2.5644e-05 - mae: 0.0039 - val_loss: 0.0029 - val_mae: 0.0390
# Epoch 72/100
# 3/3 [==============================] - 0s 12ms/step - loss: 2.6668e-05 - mae: 0.0040 - val_loss: 0.0028 - val_mae: 0.0381
# Epoch 73/100
# 3/3 [==============================] - 0s 13ms/step - loss: 2.7251e-05 - mae: 0.0041 - val_loss: 0.0030 - val_mae: 0.0399
# Epoch 74/100
# 3/3 [==============================] - 0s 14ms/step - loss: 2.4513e-05 - mae: 0.0040 - val_loss: 0.0024 - val_mae: 0.0332
# Epoch 75/100
# 3/3 [==============================] - 0s 14ms/step - loss: 3.8163e-05 - mae: 0.0049 - val_loss: 0.0025 - val_mae: 0.0344
# Epoch 76/100
# 3/3 [==============================] - 0s 12ms/step - loss: 2.5480e-05 - mae: 0.0039 - val_loss: 0.0036 - val_mae: 0.0474
# Epoch 77/100
# 3/3 [==============================] - 0s 13ms/step - loss: 5.1351e-05 - mae: 0.0057 - val_loss: 0.0033 - val_mae: 0.0434
# Epoch 78/100
# 3/3 [==============================] - 0s 13ms/step - loss: 2.6036e-05 - mae: 0.0042 - val_loss: 0.0024 - val_mae: 0.0339
# Epoch 79/100
# 3/3 [==============================] - 0s 12ms/step - loss: 3.2015e-05 - mae: 0.0044 - val_loss: 0.0026 - val_mae: 0.0362
# Epoch 80/100
# 3/3 [==============================] - 0s 13ms/step - loss: 2.3570e-05 - mae: 0.0039 - val_loss: 0.0031 - val_mae: 0.0422
# Epoch 81/100
# 3/3 [==============================] - 0s 12ms/step - loss: 2.4961e-05 - mae: 0.0039 - val_loss: 0.0027 - val_mae: 0.0374
# Epoch 82/100
# 3/3 [==============================] - 0s 11ms/step - loss: 2.4781e-05 - mae: 0.0040 - val_loss: 0.0024 - val_mae: 0.0339
# Epoch 83/100
# 3/3 [==============================] - 0s 13ms/step - loss: 2.5176e-05 - mae: 0.0040 - val_loss: 0.0030 - val_mae: 0.0402
# Epoch 84/100
# 3/3 [==============================] - 0s 13ms/step - loss: 2.3859e-05 - mae: 0.0038 - val_loss: 0.0030 - val_mae: 0.0405
# Epoch 85/100
# 3/3 [==============================] - 0s 12ms/step - loss: 2.0982e-05 - mae: 0.0035 - val_loss: 0.0025 - val_mae: 0.0351
# Epoch 86/100
# 3/3 [==============================] - 0s 13ms/step - loss: 2.6638e-05 - mae: 0.0040 - val_loss: 0.0030 - val_mae: 0.0406
# Epoch 87/100
# 3/3 [==============================] - 0s 12ms/step - loss: 2.3824e-05 - mae: 0.0038 - val_loss: 0.0029 - val_mae: 0.0400
# Epoch 88/100
# 3/3 [==============================] - 0s 13ms/step - loss: 2.1149e-05 - mae: 0.0035 - val_loss: 0.0023 - val_mae: 0.0326
# Epoch 89/100
# 3/3 [==============================] - 0s 13ms/step - loss: 2.7901e-05 - mae: 0.0043 - val_loss: 0.0025 - val_mae: 0.0349
# Epoch 90/100
# 3/3 [==============================] - 0s 12ms/step - loss: 2.0846e-05 - mae: 0.0037 - val_loss: 0.0029 - val_mae: 0.0405
# Epoch 91/100
# 3/3 [==============================] - 0s 14ms/step - loss: 2.3582e-05 - mae: 0.0039 - val_loss: 0.0029 - val_mae: 0.0402
# Epoch 92/100
# 3/3 [==============================] - 0s 13ms/step - loss: 1.9922e-05 - mae: 0.0036 - val_loss: 0.0022 - val_mae: 0.0325
# Epoch 93/100
# 3/3 [==============================] - 0s 14ms/step - loss: 2.9974e-05 - mae: 0.0044 - val_loss: 0.0023 - val_mae: 0.0327
# Epoch 94/100
# 3/3 [==============================] - 0s 14ms/step - loss: 2.2944e-05 - mae: 0.0039 - val_loss: 0.0028 - val_mae: 0.0393
# Epoch 95/100
# 3/3 [==============================] - 0s 13ms/step - loss: 2.1111e-05 - mae: 0.0037 - val_loss: 0.0027 - val_mae: 0.0379
# Epoch 96/100
# 3/3 [==============================] - 0s 12ms/step - loss: 1.8259e-05 - mae: 0.0034 - val_loss: 0.0025 - val_mae: 0.0352
# Epoch 97/100
# 3/3 [==============================] - 0s 14ms/step - loss: 1.8828e-05 - mae: 0.0035 - val_loss: 0.0025 - val_mae: 0.0361
# Epoch 98/100
# 3/3 [==============================] - 0s 14ms/step - loss: 1.8132e-05 - mae: 0.0034 - val_loss: 0.0026 - val_mae: 0.0370
# Epoch 99/100
# 3/3 [==============================] - 0s 13ms/step - loss: 1.8369e-05 - mae: 0.0034 - val_loss: 0.0025 - val_mae: 0.0364
# Epoch 100/100
# 3/3 [==============================] - 0s 14ms/step - loss: 1.9911e-05 - mae: 0.0035 - val_loss: 0.0025 - val_mae: 0.0355

# %%
# Step 6: 2022년 1월 28일 코로나 확진자 수 예측
last_sequence = covid_19.iloc[-sequence_length:][['deathCnt', 'decideCnt', 'new_patient']].values
last_sequence = np.expand_dims(last_sequence, axis=0)
predicted_value = model.predict(last_sequence)
# predicted_value = scaler.inverse_transform(predicted_value)  # 정규화된 값을 원래 범위로 변환
## 원래의 값 = (정규화된 값 * (max - min)) + min
predicted_value = (predicted_value * (14515.0 - 0.0)) + 0.0
print("2022년 1월 28일 코로나 확진자 수 예측:", predicted_value)
# Out:
# 1/1 [==============================] - 0s 167ms/step
# 2022년 1월 28일 코로나 확진자 수 예측: [[12979.332]]

# %%
df = pd.DataFrame(hist.history)
df
# Out:
#         loss       mae  val_loss   val_mae
# 0   0.063666  0.187509  0.007181  0.081099
# 1   0.022689  0.143044  0.033765  0.181249
# 2   0.015142  0.112800  0.003020  0.037941
# 3   0.001154  0.025377  0.031084  0.163994
# 4   0.010167  0.093359  0.013602  0.098266
# ..       ...       ...       ...       ...
# 95  0.000018  0.003401  0.002453  0.035207
# 96  0.000019  0.003545  0.002527  0.036124
# 97  0.000018  0.003434  0.002593  0.036981
# 98  0.000018  0.003370  0.002530  0.036380
# 99  0.000020  0.003479  0.002451  0.035512
#
# [100 rows x 4 columns]

# %%
plt.plot(df.loss, label = 'loss')
plt.plot(df.mae, label='mae')
plt.legend()
plt.show()

# %% [markdown]
# #### 데이터 정규화 및 분류하기

# %% [markdown]
# #### 데이터 형태 변경하기

# %% [markdown]
# ### 인공지능 모델 만들기

# %% [markdown]
# #### 모델 학습

# %% [markdown]
# #### 결과 시각화
